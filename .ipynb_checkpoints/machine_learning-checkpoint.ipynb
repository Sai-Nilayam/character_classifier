# %% [markdown]
# Here we are going to use our Data to Develope a Model that will take input an Image and Predict it's class.

# %%
# Makes Tensorflow showing less erros messages.
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Imports
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import random
from tensorflow import keras
from tensorflow.keras import layers

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# ## Importing Images and Data set Preparation

# %%
# Lists all the file names from the Source folder
base_path = 'data/train/training_data_resized/'

files = os.listdir(base_path)
files = [file for file in files if file[-1] != '~']

print(len(files))
# Out:
# 576

# %%
# Getting all the images in RGB formats and storing them all in a container array
classes = ['Alpha', 'Beta', 'Gamma']

X = []
y = []

for file in files:
    # Creating the File path (Image Path).
    file_path = base_path + file
    # Opening the Image using OpenCV
    inst_img = cv2.imread(file_path)
    # Converting the img to a Numpy Array
    inst_img_arr = np.array(inst_img)
    # Adding the Image Array to the Container Array. 
    X.append(inst_img_arr)
    
    # The other thing is to use grab the label from the Image name.
    inst_label = int(file[0])
    # Append the label to the 'y' Array.
    y.append(inst_label)
    
# Converting both X and y to Numpy Arrays for Efficient Computaion.
X = np.array(X)
y = np.array(y).reshape(len(X), -1)

print('Shape of X: ', X.shape)
print('Shape of y: ', y.shape)
# Out:
# Shape of X:  (576, 32, 32, 3)
# Shape of y:  (576, 1)

# %%
# Let's show one of the Image from our X Array.
index = 4

img = X[index]
# Converting BGR to RGB 
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

label = y[index][0]
class_ = classes[label]

print('Shape of the Image: ', img.shape)

plt.imshow(img)
plt.xlabel('{} - {}'.format(label, class_), size=12)
plt.show()
# Out:
# Shape of the Image:  (32, 32, 3)

# %%
# Now let's randomize the all the X and y that we have.
X_y = []
for i in range(len(X)):
    inst_arr = []
    inst_X = X[i]
    inst_y = y[i]
    inst_arr.append(inst_X)
    inst_arr.append(inst_y)
    
    X_y.append(inst_arr)

# Randomizing X_y with a Random seed 4.
random.Random(4).shuffle(X_y)

len(X_y)
# Out:
# 576

# %%
# Now we have a fully ready Feature Label Dataset.
# Now let's do a Train Dev split.
# We have tatal of 48 examples. So with this much less data let's follow the traditional rule of thumb to do a 
# 70-30 split.

cut_up = round(len(X_y)*(70/100))

Train = X_y[0:cut_up]
Dev = X_y[cut_up:]

print(len(Train))
print(len(Dev))
# Out:
# 403
# 173

# %%
# Preparing the the Trainging set in a way Tensorflow-Keras Models expect.
X_train = [ele[0] for ele in Train]
X_train = np.array(X_train)
print(X_train.shape)

y_train = [ele[1] for ele in Train]
y_train = np.array(y_train)
print(y_train.shape)

X_dev = [ele[0] for ele in Dev]
X_dev = np.array(X_dev)
print(X_dev.shape)

y_dev = [ele[1] for ele in Dev]
y_dev = np.array(y_dev)
print(y_dev.shape)
# Out:
# (403, 32, 32, 3)
# (403, 1)
# (173, 32, 32, 3)
# (173, 1)

# %%
# Actually in practice input shape is flatten. So we are going to flatted the input array.
X_train = X_train.reshape(-1, 32*32*3)
X_train.shape
# Out:
# (403, 3072)

# %% [markdown]
# ## Building a Neural Network
# In this problem we are going to use just a traditional Neural Network just having a bunch of Dense layers.

# %%
# Defining the 'Layers' with No. of 'Neurons' and 'Activatioin Functions'.
inputs = keras.Input(shape=(3072))
outputs = layers.Dense(3, activation='softmax')(inputs)

# Building the Model with the above Layers.
model = keras.Model(inputs=inputs, outputs=outputs)

# Verifying the whether the model is as per the way we want or not.
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 9219
# =================================================================
# Total params: 9,219
# Trainable params: 9,219
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Definging the 'Cost Function', 'Optimizer' and 'Evaluation Metrics' for the Model.
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.003),
    metrics=['accuracy']
)

# %%
# Training the Model.
model.fit(X_train, y_train, batch_size=len(X_train), epochs=128 + 32, verbose=2)
# Out:
# Epoch 1/160
# 1/1 - 0s - loss: 527.3545 - accuracy: 0.3251
# Epoch 2/160
# 1/1 - 0s - loss: 847.0358 - accuracy: 0.3052
# Epoch 3/160
# 1/1 - 0s - loss: 1928.5597 - accuracy: 0.3300
# Epoch 4/160
# 1/1 - 0s - loss: 1629.6182 - accuracy: 0.3300
# Epoch 5/160
# 1/1 - 0s - loss: 896.4653 - accuracy: 0.3052
# Epoch 6/160
# 1/1 - 0s - loss: 790.9595 - accuracy: 0.3449
# Epoch 7/160
# 1/1 - 0s - loss: 277.3660 - accuracy: 0.3275
# Epoch 8/160
# 1/1 - 0s - loss: 412.2918 - accuracy: 0.3251
# Epoch 9/160
# 1/1 - 0s - loss: 640.4675 - accuracy: 0.3251
# Epoch 10/160
# 1/1 - 0s - loss: 758.6198 - accuracy: 0.3300
# Epoch 11/160
# 1/1 - 0s - loss: 719.5889 - accuracy: 0.3300
# Epoch 12/160
# 1/1 - 0s - loss: 643.7290 - accuracy: 0.3251
# Epoch 13/160
# 1/1 - 0s - loss: 474.0541 - accuracy: 0.3251
# Epoch 14/160
# 1/1 - 0s - loss: 154.7015 - accuracy: 0.3474
# Epoch 15/160
# 1/1 - 0s - loss: 278.7159 - accuracy: 0.3449
# Epoch 16/160
# 1/1 - 0s - loss: 461.3369 - accuracy: 0.3449
# Epoch 17/160
# 1/1 - 0s - loss: 364.9621 - accuracy: 0.3449
# Epoch 18/160
# 1/1 - 0s - loss: 44.0740 - accuracy: 0.5782
# Epoch 19/160
# 1/1 - 0s - loss: 203.6662 - accuracy: 0.4591
# Epoch 20/160
# 1/1 - 0s - loss: 383.6621 - accuracy: 0.3350
# Epoch 21/160
# 1/1 - 0s - loss: 400.6941 - accuracy: 0.4715
# Epoch 22/160
# 1/1 - 0s - loss: 373.7904 - accuracy: 0.5459
# Epoch 23/160
# 1/1 - 0s - loss: 329.5455 - accuracy: 0.3350
# Epoch 24/160
# 1/1 - 0s - loss: 155.4803 - accuracy: 0.3797
# Epoch 25/160
# 1/1 - 0s - loss: 38.0935 - accuracy: 0.7221
# Epoch 26/160
# 1/1 - 0s - loss: 255.5345 - accuracy: 0.3449
# Epoch 27/160
# 1/1 - 0s - loss: 232.4715 - accuracy: 0.3449
# Epoch 28/160
# 1/1 - 0s - loss: 70.8361 - accuracy: 0.4566
# Epoch 29/160
# 1/1 - 0s - loss: 60.8859 - accuracy: 0.6576
# Epoch 30/160
# 1/1 - 0s - loss: 170.2781 - accuracy: 0.3300
# Epoch 31/160
# 1/1 - 0s - loss: 75.8407 - accuracy: 0.5484
# Epoch 32/160
# 1/1 - 0s - loss: 85.7804 - accuracy: 0.4491
# Epoch 33/160
# 1/1 - 0s - loss: 123.8919 - accuracy: 0.3921
# Epoch 34/160
# 1/1 - 0s - loss: 107.2428 - accuracy: 0.3797
# Epoch 35/160
# 1/1 - 0s - loss: 13.6257 - accuracy: 0.7419
# Epoch 36/160
# 1/1 - 0s - loss: 78.2232 - accuracy: 0.4764
# Epoch 37/160
# 1/1 - 0s - loss: 75.0496 - accuracy: 0.6104
# Epoch 38/160
# 1/1 - 0s - loss: 35.3140 - accuracy: 0.6526
# Epoch 39/160
# 1/1 - 0s - loss: 15.4994 - accuracy: 0.6799
# Epoch 40/160
# 1/1 - 0s - loss: 59.5416 - accuracy: 0.4194
# Epoch 41/160
# 1/1 - 0s - loss: 22.0108 - accuracy: 0.6005
# Epoch 42/160
# 1/1 - 0s - loss: 30.7181 - accuracy: 0.5658
# Epoch 43/160
# 1/1 - 0s - loss: 16.7546 - accuracy: 0.7345
# Epoch 44/160
# 1/1 - 0s - loss: 7.5400 - accuracy: 0.8412
# Epoch 45/160
# 1/1 - 0s - loss: 25.4486 - accuracy: 0.6228
# Epoch 46/160
# 1/1 - 0s - loss: 5.5038 - accuracy: 0.8288
# Epoch 47/160
# 1/1 - 0s - loss: 1.7096 - accuracy: 0.9231
# Epoch 48/160
# 1/1 - 0s - loss: 27.6261 - accuracy: 0.5012
# Epoch 49/160
# 1/1 - 0s - loss: 29.2591 - accuracy: 0.5409
# Epoch 50/160
# 1/1 - 0s - loss: 8.3210 - accuracy: 0.8114
# Epoch 51/160
# 1/1 - 0s - loss: 28.4729 - accuracy: 0.6650
# Epoch 52/160
# 1/1 - 0s - loss: 18.6252 - accuracy: 0.6873
# Epoch 53/160
# 1/1 - 0s - loss: 2.2680 - accuracy: 0.9082
# Epoch 54/160
# 1/1 - 0s - loss: 36.6226 - accuracy: 0.5707
# Epoch 55/160
# 1/1 - 0s - loss: 5.0025 - accuracy: 0.8486
# Epoch 56/160
# 1/1 - 0s - loss: 9.7298 - accuracy: 0.7543
# Epoch 57/160
# 1/1 - 0s - loss: 18.1381 - accuracy: 0.7122
# Epoch 58/160
# 1/1 - 0s - loss: 5.4678 - accuracy: 0.8734
# Epoch 59/160
# 1/1 - 0s - loss: 11.5210 - accuracy: 0.7345
# Epoch 60/160
# 1/1 - 0s - loss: 1.4096 - accuracy: 0.9454
# Epoch 61/160
# 1/1 - 0s - loss: 34.4572 - accuracy: 0.4640
# Epoch 62/160
# 1/1 - 0s - loss: 2.2111 - accuracy: 0.9305
# Epoch 63/160
# 1/1 - 0s - loss: 44.0090 - accuracy: 0.6700
# Epoch 64/160
# 1/1 - 0s - loss: 27.4180 - accuracy: 0.6576
# Epoch 65/160
# 1/1 - 0s - loss: 2.4814 - accuracy: 0.9305
# Epoch 66/160
# 1/1 - 0s - loss: 33.7779 - accuracy: 0.5558
# Epoch 67/160
# 1/1 - 0s - loss: 1.2005 - accuracy: 0.9454
# Epoch 68/160
# 1/1 - 0s - loss: 32.1491 - accuracy: 0.5459
# Epoch 69/160
# 1/1 - 0s - loss: 0.8188 - accuracy: 0.9752
# Epoch 70/160
# 1/1 - 0s - loss: 19.8930 - accuracy: 0.6948
# Epoch 71/160
# 1/1 - 0s - loss: 6.8442 - accuracy: 0.8263
# Epoch 72/160
# 1/1 - 0s - loss: 0.5112 - accuracy: 0.9826
# Epoch 73/160
# 1/1 - 0s - loss: 20.2075 - accuracy: 0.6948
# Epoch 74/160
# 1/1 - 0s - loss: 3.0197 - accuracy: 0.9082
# Epoch 75/160
# 1/1 - 0s - loss: 2.4706 - accuracy: 0.9429
# Epoch 76/160
# 1/1 - 0s - loss: 15.1948 - accuracy: 0.6998
# Epoch 77/160
# 1/1 - 0s - loss: 2.8657 - accuracy: 0.9355
# Epoch 78/160
# 1/1 - 0s - loss: 19.4001 - accuracy: 0.7419
# Epoch 79/160
# 1/1 - 0s - loss: 7.3886 - accuracy: 0.8685
# Epoch 80/160
# 1/1 - 0s - loss: 0.5461 - accuracy: 0.9826
# Epoch 81/160
# 1/1 - 0s - loss: 10.9191 - accuracy: 0.6898
# Epoch 82/160
# 1/1 - 0s - loss: 0.5453 - accuracy: 0.9826
# Epoch 83/160
# 1/1 - 0s - loss: 3.0564 - accuracy: 0.9231
# Epoch 84/160
# 1/1 - 0s - loss: 6.2639 - accuracy: 0.8635
# Epoch 85/160
# 1/1 - 0s - loss: 1.1530 - accuracy: 0.9727
# Epoch 86/160
# 1/1 - 0s - loss: 0.6474 - accuracy: 0.9801
# Epoch 87/160
# 1/1 - 0s - loss: 3.7387 - accuracy: 0.8983
# Epoch 88/160
# 1/1 - 0s - loss: 3.1125 - accuracy: 0.9454
# Epoch 89/160
# 1/1 - 0s - loss: 0.9392 - accuracy: 0.9702
# Epoch 90/160
# 1/1 - 0s - loss: 0.5397 - accuracy: 0.9851
# Epoch 91/160
# 1/1 - 0s - loss: 1.2298 - accuracy: 0.9702
# Epoch 92/160
# 1/1 - 0s - loss: 2.3909 - accuracy: 0.9454
# Epoch 93/160
# 1/1 - 0s - loss: 1.2048 - accuracy: 0.9727
# Epoch 94/160
# 1/1 - 0s - loss: 0.5183 - accuracy: 0.9801
# Epoch 95/160
# 1/1 - 0s - loss: 0.6163 - accuracy: 0.9851
# Epoch 96/160
# 1/1 - 0s - loss: 1.3530 - accuracy: 0.9677
# Epoch 97/160
# 1/1 - 0s - loss: 1.5341 - accuracy: 0.9653
# Epoch 98/160
# 1/1 - 0s - loss: 0.8489 - accuracy: 0.9777
# Epoch 99/160
# 1/1 - 0s - loss: 0.4994 - accuracy: 0.9851
# Epoch 100/160
# 1/1 - 0s - loss: 0.6263 - accuracy: 0.9752
# Epoch 101/160
# 1/1 - 0s - loss: 1.0415 - accuracy: 0.9777
# Epoch 102/160
# 1/1 - 0s - loss: 1.1597 - accuracy: 0.9727
# Epoch 103/160
# 1/1 - 0s - loss: 0.8005 - accuracy: 0.9826
# Epoch 104/160
# 1/1 - 0s - loss: 0.4588 - accuracy: 0.9801
# Epoch 105/160
# 1/1 - 0s - loss: 0.4074 - accuracy: 0.9876
# Epoch 106/160
# 1/1 - 0s - loss: 0.5888 - accuracy: 0.9826
# Epoch 107/160
# 1/1 - 0s - loss: 0.7938 - accuracy: 0.9777
# Epoch 108/160
# 1/1 - 0s - loss: 0.6636 - accuracy: 0.9801
# Epoch 109/160
# 1/1 - 0s - loss: 0.4237 - accuracy: 0.9901
# Epoch 110/160
# 1/1 - 0s - loss: 0.3578 - accuracy: 0.9876
# Epoch 111/160
# 1/1 - 0s - loss: 0.4083 - accuracy: 0.9826
# Epoch 112/160
# 1/1 - 0s - loss: 0.5490 - accuracy: 0.9851
# Epoch 113/160
# 1/1 - 0s - loss: 0.5586 - accuracy: 0.9851
# Epoch 114/160
# 1/1 - 0s - loss: 0.4091 - accuracy: 0.9826
# Epoch 115/160
# 1/1 - 0s - loss: 0.3076 - accuracy: 0.9876
# Epoch 116/160
# 1/1 - 0s - loss: 0.3084 - accuracy: 0.9876
# Epoch 117/160
# 1/1 - 0s - loss: 0.3718 - accuracy: 0.9901
# Epoch 118/160
# 1/1 - 0s - loss: 0.4297 - accuracy: 0.9826
# Epoch 119/160
# 1/1 - 0s - loss: 0.3639 - accuracy: 0.9901
# Epoch 120/160
# 1/1 - 0s - loss: 0.2844 - accuracy: 0.9901
# Epoch 121/160
# 1/1 - 0s - loss: 0.2489 - accuracy: 0.9901
# Epoch 122/160
# 1/1 - 0s - loss: 0.2447 - accuracy: 0.9901
# Epoch 123/160
# 1/1 - 0s - loss: 0.3064 - accuracy: 0.9901
# Epoch 124/160
# 1/1 - 0s - loss: 0.2853 - accuracy: 0.9901
# Epoch 125/160
# 1/1 - 0s - loss: 0.2154 - accuracy: 0.9926
# Epoch 126/160
# 1/1 - 0s - loss: 0.2050 - accuracy: 0.9901
# Epoch 127/160
# 1/1 - 0s - loss: 0.2057 - accuracy: 0.9926
# Epoch 128/160
# 1/1 - 0s - loss: 0.2197 - accuracy: 0.9926
# Epoch 129/160
# 1/1 - 0s - loss: 0.2224 - accuracy: 0.9901
# Epoch 130/160
# 1/1 - 0s - loss: 0.2010 - accuracy: 0.9926
# Epoch 131/160
# 1/1 - 0s - loss: 0.1751 - accuracy: 0.9926
# Epoch 132/160
# 1/1 - 0s - loss: 0.1526 - accuracy: 0.9901
# Epoch 133/160
# 1/1 - 0s - loss: 0.1587 - accuracy: 0.9926
# Epoch 134/160
# 1/1 - 0s - loss: 0.1678 - accuracy: 0.9950
# Epoch 135/160
# 1/1 - 0s - loss: 0.1627 - accuracy: 0.9950
# Epoch 136/160
# 1/1 - 0s - loss: 0.1398 - accuracy: 0.9926
# Epoch 137/160
# 1/1 - 0s - loss: 0.1219 - accuracy: 0.9950
# Epoch 138/160
# 1/1 - 0s - loss: 0.1212 - accuracy: 0.9926
# Epoch 139/160
# 1/1 - 0s - loss: 0.1261 - accuracy: 0.9926
# Epoch 140/160
# 1/1 - 0s - loss: 0.1220 - accuracy: 0.9926
# Epoch 141/160
# 1/1 - 0s - loss: 0.1104 - accuracy: 0.9950
# Epoch 142/160
# 1/1 - 0s - loss: 0.1042 - accuracy: 0.9950
# Epoch 143/160
# 1/1 - 0s - loss: 0.0994 - accuracy: 0.9950
# Epoch 144/160
# 1/1 - 0s - loss: 0.0951 - accuracy: 0.9950
# Epoch 145/160
# 1/1 - 0s - loss: 0.0963 - accuracy: 0.9975
# Epoch 146/160
# 1/1 - 0s - loss: 0.0956 - accuracy: 0.9975
# Epoch 147/160
# 1/1 - 0s - loss: 0.0889 - accuracy: 0.9975
# Epoch 148/160
# 1/1 - 0s - loss: 0.0828 - accuracy: 0.9950
# Epoch 149/160
# 1/1 - 0s - loss: 0.0807 - accuracy: 0.9950
# Epoch 150/160
# 1/1 - 0s - loss: 0.0786 - accuracy: 0.9950
# Epoch 151/160
# 1/1 - 0s - loss: 0.0763 - accuracy: 0.9950
# Epoch 152/160
# 1/1 - 0s - loss: 0.0739 - accuracy: 0.9950
# Epoch 153/160
# 1/1 - 0s - loss: 0.0713 - accuracy: 0.9950
# Epoch 154/160
# 1/1 - 0s - loss: 0.0686 - accuracy: 0.9950
# Epoch 155/160
# 1/1 - 0s - loss: 0.0657 - accuracy: 0.9950
# Epoch 156/160
# 1/1 - 0s - loss: 0.0627 - accuracy: 0.9950
# Epoch 157/160
# 1/1 - 0s - loss: 0.0597 - accuracy: 0.9950
# Epoch 158/160
# 1/1 - 0s - loss: 0.0565 - accuracy: 0.9950
# Epoch 159/160
# 1/1 - 0s - loss: 0.0532 - accuracy: 0.9950
# Epoch 160/160
# 1/1 - 0s - loss: 0.0498 - accuracy: 0.9950

# %%
# Before Evaluating let's make the X_dev flattern.
X_dev = X_dev.reshape(-1, 32*32*3)

# Evaluating the Model
print(model.evaluate(X_dev, y_dev, batch_size=len(X_dev), verbose=2))
# Out:
# 1/1 - 0s - loss: 0.4510 - accuracy: 0.9827
# [0.451010525226593, 0.9826589822769165]

# %%
# Saving the Model.
# model.save('models/model_1/')

# %% [markdown]
# ## Model Building Completed
# From the above Evaluation it seems that our Model is getting an Accuracy of 100%.
#
# This is awesome. Let's Test our Model to know how it performs for purely unseed data.

# %% [markdown]
# ## Model Testing

# %%
# Importing the Model.
model_test = tf.keras.models.load_model('models/model_1/')

model_test.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 9219
# =================================================================
# Total params: 9,219
# Trainable params: 9,219
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Importing the Test Data and Preprosess it to the format our model is expecting.

# Lists all the file names from the Source folder
base_path = 'data/test_2/testing_data_resized/'

files = os.listdir(base_path)
files = [file for file in files if file[-1] != '~']

print(len(files))

# Getting all the images in RGB formats and storing them all in a container array
classes = ['Alpha', 'Beta', 'Gamma']

X_test = []
y_test = []

for file in files:
    # Creating the File path (Image Path).
    file_path = base_path + file
    # Opening the Image using OpenCV
    inst_img = cv2.imread(file_path)
    # Converting the img to a Numpy Array
    inst_img_arr = np.array(inst_img)
    # Adding the Image Array to the Container Array. 
    X_test.append(inst_img_arr)
    
    # The other thing is to use grab the label from the Image name.
    inst_label = int(file[0])
    # Append the label to the 'y' Array.
    y_test.append(inst_label)
    
# Converting both X and y to Numpy Arrays for Efficient Computaion.
X_test = np.array(X_test)
y_test = np.array(y_test).reshape(len(X_test), -1)

print('Shape of X_test: ', X_test.shape)
print('Shape of y_test: ', y_test.shape)
# Out:
# 48
# Shape of X_test:  (48, 32, 32, 3)
# Shape of y_test:  (48, 1)

# %%
# Visualizing our Test Data
def plot(index):
    index = index

    img = X_test[index]
    label = y_test[index][0]
    class_ = classes[label]

    print('Shape of the Image: ', img.shape)

    plt.imshow(img)
    plt.xlabel('{} - {}'.format(label, class_), size=12)
    plt.show()
    
for i in range(2):
    plot(i)
# Out:
# Shape of the Image:  (32, 32, 3)
# Shape of the Image:  (32, 32, 3)

# %%
# Reshaping our Data Arrays.
# Reshapeing the X and y
X_test = X_test.reshape(-1, 32*32*3)

print(X_test.shape)
# Out:
# (48, 3072)

# %%
# Evaluating our Model on Test Data.
print(model_test.evaluate(X_test, y_test, batch_size=len(X_test), verbose=2))
# Out:
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000
# [0.0, 1.0]

# %% [markdown]
# ## Trying out some Traditional Learning Algorithms

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
# Setting data to flatten array for the following estimators
X_train_flatten = X_train.reshape(403, -1)
X_dev_flatten = X_dev.reshape(173, -1)

# %%
# Logistic Regression
model_t = LogisticRegression()
print(model_t)
model_t.fit(X_train_flatten, y_train)
predictions = model_t.predict(X_dev_flatten)
accuracy = accuracy_score(y_dev, predictions)
print(accuracy)
# Out:
# LogisticRegression()
# /home/sai-nilayam/personal/dev/venvs/tf/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 1.0
# /home/sai-nilayam/personal/dev/venvs/tf/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# SVM
model_t = SVC(kernel='linear')
print(model_t)
model_t.fit(X_train_flatten, y_train)
predictions = model_t.predict(X_dev_flatten)
accuracy = accuracy_score(y_dev, predictions)
print(accuracy)
# Out:
# SVC(kernel='linear')
# 1.0
# /home/sai-nilayam/personal/dev/venvs/tf/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
# KNN
model_t = KNeighborsClassifier(n_neighbors=1)
print(model_t)
model_t.fit(X_train_flatten, y_train)
predictions = model_t.predict(X_dev_flatten)
accuracy = accuracy_score(y_dev, predictions)
print(accuracy)
# Out:
# KNeighborsClassifier(n_neighbors=1)
# 0.9942196531791907
# /home/sai-nilayam/personal/dev/venvs/tf/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
# Tree Based
# Decision Tree
model_t = DecisionTreeClassifier()
print(model_t)
model_t.fit(X_train_flatten, y_train)
predictions = model_t.predict(X_dev_flatten)
accuracy = accuracy_score(y_dev, predictions)
print(accuracy)

# Random Forest
model_t = RandomForestClassifier()
print(model_t)
model_t.fit(X_train_flatten, y_train)
predictions = model_t.predict(X_dev_flatten)
accuracy = accuracy_score(y_dev, predictions)
print(accuracy)
# Out:
# DecisionTreeClassifier()
# 0.8728323699421965
# RandomForestClassifier()
# /tmp/ipykernel_104520/1685813210.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_t.fit(X_train_flatten, y_train)
# 1.0

# %%
# Naive Bayes
# Gausian Naive Bayer
model_t = GaussianNB()
print(model_t)
model_t.fit(X_train_flatten, y_train)
predictions = model_t.predict(X_dev_flatten)
accuracy = accuracy_score(y_dev, predictions)
print(accuracy)

# Multinomial Navie Bayes
model_t = MultinomialNB()
print(model_t)
model_t.fit(X_train_flatten, y_train)
predictions = model_t.predict(X_dev_flatten)
accuracy = accuracy_score(y_dev, predictions)
print(accuracy)
# Out:
# GaussianNB()
# 0.8092485549132948
# MultinomialNB()
# 0.7052023121387283
# /home/sai-nilayam/personal/dev/venvs/tf/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /home/sai-nilayam/personal/dev/venvs/tf/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %% [markdown]
# ## Trying some Statistics

# %%
class_ = 0
all_one_class = []

for i in range(len(X)):
    if y[i][0] == class_:
        all_one_class.append(X[i])

all_one_class = np.array(all_one_class)

print(all_one_class.shape)
# Out:
# (192, 32, 32, 3)

# %%
all_one_class_mean = np.mean(all_one_class, axis=0)
print(all_one_class_mean.shape)
# Out:
# (32, 32, 3)

# %%
# Let's plot it.
int_all_one_class_mean = all_one_class_mean.astype(int)

plt.imshow(int_all_one_class_mean)
plt.show()

# %%
# Let's findout mean of means.
mean_real = np.sum(all_one_class_mean)/(32*32*3)
print(mean_real)

# Let's findout what is the Standard Deviation
all_one_class_std = np.std(all_one_class, axis=0)
# print(all_one_class_std)
std_real = np.sum(all_one_class_std)/(32*32*3)
print(std_real)
# Out:
# 158.32011074490018
# 33.978235652039025

# %%
165.15604485405817
35.23978767469223

167.48965793185764
37.0291255334921

158.32011074490018
33.978235652039025
